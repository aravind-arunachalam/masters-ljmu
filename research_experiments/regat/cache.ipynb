# %%
import pickle

# %%
train_a2l_pkl = open("/python-workdir/VQA_ReGAT/data/cache/trainval_ans2label.pkl","rb")
train_a2l = pickle.load(train_a2l_pkl)
train_a2l
# Out:
# {'net': 0,
#  'pitcher': 1,
#  'orange': 2,
#  'yes': 3,
#  'white': 4,
#  'skiing': 5,
#  'red': 6,
#  'frisbee': 7,
#  'brushing teeth': 8,
#  'no': 9,
#  'black and white': 10,
#  'skateboard': 11,
#  '1': 12,
#  'blue': 13,
#  'green': 14,
#  'motorcycle': 15,
#  'gray': 16,
#  '2': 17,
#  'purse': 18,
#  'skis': 19,
#  'poles': 20,
#  'surfboard': 21,
#  'dog': 22,
#  'on': 23,
#  'office': 24,
#  'large': 25,
#  'very big': 26,
#  'laptop': 27,
#  'vent': 28,
#  'computer': 29,
#  'black': 30,
#  'bear': 31,
#  '3': 32,
#  'wii': 33,
#  'glasses': 34,
#  'tree': 35,
#  'eating': 36,
#  'log': 37,
#  '5': 38,
#  'raft': 39,
#  'left': 40,
#  'living room': 41,
#  'pink': 42,
#  'right': 43,
#  'railing': 44,
#  'grass': 45,
#  'wire': 46,
#  '10 years': 47,
#  'knife': 48,
#  'cake': 49,
#  'banana': 50,
#  'chef': 51,
#  'vanilla': 52,
#  '4': 53,
#  'outdoor': 54,
#  'mustard': 55,
#  'bun': 56,
#  'clouds': 57,
#  'dock': 58,
#  'brown': 59,
#  'silver': 60,
# ...

# %%
train_l2a_pkl = open("trainval_label2ans.pkl","rb")
train_l2a = pickle.load(train_l2a_pkl)
train_l2a
# Out:
# ['net',
#  'pitcher',
#  'orange',
#  'yes',
#  'white',
#  'skiing',
#  'red',
#  'frisbee',
#  'brushing teeth',
#  'no',
#  'black and white',
#  'skateboard',
#  '1',
#  'blue',
#  'green',
#  'motorcycle',
#  'gray',
#  '2',
#  'purse',
#  'skis',
#  'poles',
#  'surfboard',
#  'dog',
#  'on',
#  'office',
#  'large',
#  'very big',
#  'laptop',
#  'vent',
#  'computer',
#  'black',
#  'bear',
#  '3',
#  'wii',
#  'glasses',
#  'tree',
#  'eating',
#  'log',
#  '5',
#  'raft',
#  'left',
#  'living room',
#  'pink',
#  'right',
#  'railing',
#  'grass',
#  'wire',
#  '10 years',
#  'knife',
#  'cake',
#  'banana',
#  'chef',
#  'vanilla',
#  '4',
#  'outdoor',
#  'mustard',
#  'bun',
#  'clouds',
#  'dock',
#  'brown',
#  'silver',
#  'refrigerator',
#  'square',
#  'teddy',
#  'elm',
#  'stripes',
#  'baseball',
#  'catcher',
#  'beer',
#  'bottom',
#  'north',
#  'nike',
#  'yellow and white',
#  'morning',
#  'elephant',
#  'red and white',
#  'propeller',
#  'tan',
# ...

# %%
train_target_pkl = open("train_target.pkl","rb")
train_target = pickle.load(train_target_pkl)
train_target
# Out:
# [{'question_id': 458752000,
#   'image_id': 458752,
#   'labels': [0],
#   'scores': [1.0]},
#  {'question_id': 458752001,
#   'image_id': 458752,
#   'labels': [1, 67],
#   'scores': [1.0, 0.3]},
#  {'question_id': 458752002,
#   'image_id': 458752,
#   'labels': [2],
#   'scores': [1.0]},
#  {'question_id': 458752003,
#   'image_id': 458752,
#   'labels': [3, 9],
#   'scores': [1.0, 0.3]},
#  {'question_id': 262146000,
#   'image_id': 262146,
#   'labels': [4],
#   'scores': [1.0]},
#  {'question_id': 262146001,
#   'image_id': 262146,
#   'labels': [5],
#   'scores': [1.0]},
#  {'question_id': 262146002,
#   'image_id': 262146,
#   'labels': [6, 30, 75],
#   'scores': [1.0, 0.3, 0.3]},
#  {'question_id': 524291000,
#   'image_id': 524291,
#   'labels': [7],
#   'scores': [1.0]},
#  {'question_id': 524291001,
#   'image_id': 524291,
#   'labels': [3],
#   'scores': [1.0]},
#  {'question_id': 524291002,
#   'image_id': 524291,
#   'labels': [7],
#   'scores': [1.0]},
# ...
