# %%
import json
import pandas as pd
import numpy as np
import h5py

# %%
with h5py.File('./train36.hdf5', 'r') as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]

    # Get the data
    image_bb = f['image_bb']
    print(image_bb[10])
    print(image_bb[10].shape)
    
    image_features = f['image_features']
    print(image_features[10])
    print(image_features[10].shape)
    
    spatial_features = f['spatial_features']
    print(spatial_features[10])
    print(spatial_features[10].shape)
# Out:
# Keys: <KeysViewHDF5 ['image_adj_matrix', 'image_bb', 'image_features', 'semantic_adj_matrix', 'spatial_features']>
# [[196.81091  156.73935  358.78738  416.65347 ]
#  [  0.        21.660223 479.2      124.9926  ]
#  [361.74655  191.01743  405.17258  226.21309 ]
#  [283.02136  180.54141  391.17728  301.35675 ]
#  [338.87506  268.53226  368.1918   292.85834 ]
#  [414.07846   78.78068  437.07428  143.54759 ]
#  [271.49097  205.20576  311.10336  237.63457 ]
#  [280.17676  211.44302  313.05786  242.91992 ]
#  [  5.886853 136.83577  164.62363  407.9015  ]
#  [247.20694  318.8687   306.02277  480.17807 ]
#  [  0.       276.732    211.94844  639.2     ]
#  [ 70.18323  346.27496  479.2      639.2     ]
#  [174.20967   69.37512  192.33931  116.52948 ]
#  [177.42313  274.16925  241.9365   404.30884 ]
#  [235.5671   183.24365  479.2      639.2     ]
#  [  0.         0.       364.7429   421.69043 ]
#  [157.56534  255.2026   216.25626  411.8378  ]
#  [ 37.16311  100.75804  471.58896  211.29825 ]
# ...
